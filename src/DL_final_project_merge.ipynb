# %%
import torch
import torch.nn as nn
from functools import reduce
from operator import __add__

class ResBlock(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super(ResBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.prelu = nn.PReLU()

        self.kernel_sizes = (3, 3)
        self.conv_padding = reduce(__add__, 
            [(k // 2 + (k - 2 * (k // 2)) - 1, k // 2) for k in self.kernel_sizes[::-1]])

    def forward(self, input):
        residual = input
        x = nn.ZeroPad2d(self.conv_padding)(input)
        x = self.bn1(self.conv1(x))
        x = self.prelu(x)
        x = nn.ZeroPad2d(self.conv_padding)(input)
        x = self.bn2(self.conv2(x))
        x += residual
        return x

class NoiseGenerator(nn.Module):
    def __init__(self, block, num_of_resblock=5, input_channels=3):
        super(NoiseGenerator, self).__init__()

        self.conv1 = nn.Conv2d(input_channels, 3, kernel_size=3, bias=False)
        self.bn1 = nn.BatchNorm2d(3)
        self.relu1 = nn.ReLU(inplace=True)
        
        self.layers = self._make_layer(block, num_of_resblock)

        self.conv2 = nn.Conv2d(input_channels, 3, kernel_size=3, bias=False)
        self.bn2 = nn.BatchNorm2d(3)
        self.relu2 = nn.ReLU(inplace=True)

        self.conv3 = nn.Conv2d(input_channels, 3, kernel_size=3, bias=False)
        self.bn3 = nn.BatchNorm2d(3)
        self.relu3 = nn.ReLU(inplace=True)

        self.kernel_sizes = (3, 3)
        self.conv_padding = reduce(__add__, 
            [(k // 2 + (k - 2 * (k // 2)) - 1, k // 2) for k in self.kernel_sizes[::-1]])

    def _make_layer(self, block, num_of_resblock):
        layers = []
        for i in range(num_of_resblock):
          layers.append(block(in_channels=3, out_channels=3))
        return nn.Sequential(*layers)

    def forward(self, input):
        x = nn.ZeroPad2d(self.conv_padding)(input)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)

        residual = x

        x = self.layers(x)

        x = nn.ZeroPad2d(self.conv_padding)(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)

        comb = x + residual

        comb = nn.ZeroPad2d(self.conv_padding)(comb)
        comb = self.conv3(comb)
        comb = self.bn3(comb)
        comb = self.relu3(comb)

        return comb

# %%
# model = NoiseGenerator(ResBlock)
# print(model)
# input = torch.ones([4,3,28,28])
# output = model(input)
# print(output.shape)

# %%
import torch
import torch.nn as nn
from functools import reduce
from operator import __add__

class ConvLayer(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, stride=2):
        super(ConvLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, 3, stride=stride, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.lrelu = nn.LeakyReLU(negative_slope=0.2)

    def forward(self, input):
        x = self.bn(self.conv(input))
        # print(x.shape)
        x = self.lrelu(x)
        return x

class Discriminator(nn.Module):
    def __init__(self, block, input_channels=3):
        super(Discriminator, self).__init__()

        self.conv1 = nn.Conv2d(input_channels, 3, kernel_size=3, padding='same', bias=False)
        self.bn1 = nn.BatchNorm2d(3)
        self.relu1 = nn.LeakyReLU(negative_slope=0.2)
        self.channels = [64, 128, 128, 256, 256, 512, 512]
        self.strides = [2, 1, 2, 1, 2, 1, 2]
        self.layers = self._make_layer(block, self.channels, self.strides)

        self.flat = nn.Flatten()
        self.dense = nn.LazyLinear (out_features=1024)
        self.relu2 = nn.LeakyReLU(negative_slope=0.2)
        self.dense2 = nn.Linear(1024, 1)
        self.sig = nn.Sigmoid()


    def _make_layer(self, block, chennels_num, strides):
        layers = []
        layers.append(block(in_channels=3, out_channels=chennels_num[0], stride = strides[0]))
        for i in range(1,len(chennels_num)-1):
          layers.append(block(in_channels=chennels_num[i-1], out_channels=chennels_num[i], stride = strides[i]))
        layers.append(block(in_channels=chennels_num[-2], out_channels=chennels_num[-1], stride = strides[-1]))
        return nn.Sequential(*layers)

    def forward(self, input):
        x = self.conv1(input)
        x = self.bn1(x)
        x = self.relu1(x)
        print(x.shape)

        x = self.layers(x)
        print(x.shape)
        x = self.flat(x)
        x = self.dense(x)
        x = self.relu2(x)
        x = self.dense2(x)
        x = self.sig(x)


        return x

# %%
# model = Discriminator(ConvLayer)
# print(model)
# input = torch.ones([4,3,64,64])
# output = model(input)
# print(output.shape)

# %%
import ddp
from ddp import Unet
from data import DatasetLoader
import torch
from torch.optim import Adam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# LOAD MODEL
ddp.MODEL.load_state_dict(torch.load("unet_final.pt"))
ddp.MODEL.to(device)
ddp.BATCH_SIZE=16
NormalDataloader = DatasetLoader("./data/dataset_same_size/train/good",batch=ddp.BATCH_SIZE,size=ddp.IMG_SIZE)
AnomalyDataloader = DatasetLoader("./data/dataset_same_size/train/defect",batch=ddp.BATCH_SIZE,size=ddp.IMG_SIZE)

# %%
# Instantiate generator and discriminator
generator = NoiseGenerator(ResBlock)
discriminator = Discriminator(ConvLayer)
forward = ddp.forward
reverse = ddp.denoise

# Specify loss functions
gan_loss = nn.BCELoss()
aux_loss = nn.MSELoss()  # Change to the appropriate loss function for your task

# Set up optimizers
generator_optimizer = torch.optim.Adam(generator.parameters(), lr=0.01)
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.01)

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    for Anomaly, Normal in zip(AnomalyDataloader, NormalDataloader): #normal 不夠的話請用data augmentation補充到跟所有anomaly相同的數量(或是刪掉幾張anomaly)
        print(Anomaly.shape)
        # ============= setting ==========
        batch_size = Anomaly.size(0)

        # Generate fake images
        generated_noise = generator(Anomaly)
        Noised_anomaly = generated_noise + Anomaly

        # Generate noised normal images
        #Noised_normal = forward(Normal, batch=ddp.BATCH_SIZE)
        Noised_normal = forward(Normal, batch=batch_size)

        # Generate Denoised images
        Denoised_normal = reverse(Noised_normal)
        Denoised_anomaly = reverse(Noised_anomaly)


        # =========== Training ==========
        # Train the discriminator
        discriminator_optimizer.zero_grad()
        
        real_labels = torch.ones(batch_size, 1)
        fake_labels = torch.zeros(batch_size, 1)
        
        real_outputs = discriminator(Noised_anomaly)
        fake_outputs = discriminator(Noised_normal)
        
        discriminator_loss = gan_loss(real_outputs, real_labels) + gan_loss(fake_outputs, fake_labels)
        discriminator_loss.backward(retain_graph=True)
        discriminator_optimizer.step()
        
        # Train the generator
        generator_optimizer.zero_grad()
        
        fake_outputs = discriminator(Noised_anomaly)
        
        generator_loss = gan_loss(fake_outputs, real_labels)
        ## generator_loss.backward()
        ## generator_optimizer.step()
        
        # Compute auxiliary loss
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [2/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.229438781738281
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [2/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.74142837524414
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [2/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.956111907958984
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# Epoch [2/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 16.068410873413086
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.096664428710938
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 15.72735595703125
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.837409973144531
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.432846069335938
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 7.8780837059021
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.259085655212402
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.759356498718262
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 3.994659423828125
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.519119262695312
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.48844051361084
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.925646781921387
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.979586601257324
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.690187454223633
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.110095977783203
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 6.486069679260254
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 15.478139877319336
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [3/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.859797477722168
# torch.Size([16, 3, 256, 256])
# ...
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [5/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.897662162780762
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 512, 13, 13])
# Epoch [5/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 16.007747650146484
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.114110946655273
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 15.692617416381836
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.8192777633667
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.461671829223633
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 7.850849151611328
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.270696640014648
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.73062515258789
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 3.964448928833008
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.552568435668945
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 13.569372177124023
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.864432334899902
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.012636184692383
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.728888511657715
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.048742294311523
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 6.4422197341918945
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 15.534296989440918
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.837692260742188
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.172395706176758
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.692398071289062
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.649859428405762
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 12.383273124694824
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.08151626586914
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.030512809753418
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.794658660888672
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 5.297758102416992
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.922465324401855
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.488492965698242
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.506296157836914
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.139404296875
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.158239364624023
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.945756912231445
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 12.485633850097656
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 16.836679458618164
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 7.236022472381592
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 8.161951065063477
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.575596809387207
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 8.715285301208496
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 10.430378913879395
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 12.024370193481445
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 9.285015106201172
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 12.402751922607422
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 11.108596801757812
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 512, 13, 13])
# Epoch [6/100], Generator Loss: 100.0, Discriminator Loss: 100.0, Auxiliary Loss: 14.508254051208496
# torch.Size([16, 3, 256, 256])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 33
#      31 # Generate Denoised images
#      32 Denoised_normal = reverse(Noised_normal)
# ---> 33 Denoised_anomaly = reverse(Noised_anomaly)
#      36 # =========== Training ==========
#      37 # Train the discriminator
#      38 discriminator_optimizer.zero_grad()
#
# File c:\Users\acvlab\Desktop\ddpm_gan\ddp.py:296, in denoise(image)
#     294     for i in range(0,T)[::-1]:
#     295         t = torch.full((1,), i, device=device, dtype=torch.long)
# --> 296         image=sample_timestep(torch.tensor(image,device=device),t)
#     297         #show_tensor_image(image.detach().to('cpu'))
#     298
#     299     #t1=show_tensor_image(image.detach().to('cpu'))
#     300 return image
#
# File c:\Users\acvlab\anaconda3\envs\hwf\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\acvlab\Desktop\ddpm_gan\ddp.py:174, in sample_timestep(x, t)
#     170 # Call model (current image - noise prediction)
#     171 model_mean = sqrt_recip_alphas_t * (
#     172     x - betas_t * MODEL(x, t) / sqrt_one_minus_alphas_cumprod_t
#     173 )
# --> 174 posterior_variance_t = get_index_from_list(posterior_variance, t, x.shape)
#     176 if t == 0:
#     177     return model_mean
#
# File c:\Users\acvlab\Desktop\ddpm_gan\ddp.py:32, in get_index_from_list(vals, t, x_shape)
#      26 """
#      27 Returns values from vals for corresponding timesteps
#      28 while considering the batch dimension.
#      29
#      30 """
#      31 batch_size = t.shape[0]
# ---> 32 output = vals.gather(-1, t.cpu())
#      33 return output.reshape(batch_size, *((1,) * (len(x_shape) - 1))).to(t.device)
#
# KeyboardInterrupt:
